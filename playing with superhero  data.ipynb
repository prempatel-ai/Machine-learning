# %%
import pandas as pd

# %%
df = pd.read_csv('dataset/marvel.csv')

# %%
df
# Out:
#         ID                              Movie         Year  \
# 0        0                           Eternals        -2021
# 1        1                               Loki     (2021– )
# 2        2  The Falcon and the Winter Soldier        -2021
# 3        3                        WandaVision        -2021
# 4        4            Spider-Man: No Way Home        -2021
# ...    ...                                ...          ...
# 1685  1685           DC's Legends of Tomorrow     (2016– )
# 1686  1686                          Supergirl  (2015–2021)
# 1687  1687                          Supergirl  (2015–2021)
# 1688  1688                          Supergirl  (2015–2021)
# 1689  1689                          Supergirl  (2015–2021)
#
#                          Genre  RunTime  \
# 0       Action,Adventure,Drama        0
# 1     Action,Adventure,Fantasy        0
# 2       Action,Adventure,Drama   50 min
# 3          Action,Comedy,Drama  350 min
# 4      Action,Adventure,Sci-Fi        0
# ...

# %%
df.head()
# Out:
#    ID                              Movie      Year                     Genre  \
# 0   0                           Eternals     -2021    Action,Adventure,Drama
# 1   1                               Loki  (2021– )  Action,Adventure,Fantasy
# 2   2  The Falcon and the Winter Soldier     -2021    Action,Adventure,Drama
# 3   3                        WandaVision     -2021       Action,Comedy,Drama
# 4   4            Spider-Man: No Way Home     -2021   Action,Adventure,Sci-Fi
#
#    RunTime                                        Description  IMDB_Score
# 0        0  The saga of the Eternals, a race of immortal b...         0.0
# 1        0      A new Marvel chapter with Loki at its center.         0.0
# 2   50 min  Following the events of 'Avengers: Endgame,' S...         7.5
# 3  350 min  Blends the style of classic sitcoms with the M...         8.1
# 4        0       A continuation of Spider-Man: Far From Home.         0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1690 entries, 0 to 1689
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           1690 non-null   int64
#  1   Movie        1690 non-null   object
#  2   Year         1657 non-null   object
#  3   Genre        1683 non-null   object
#  4   RunTime      1690 non-null   object
#  5   Description  1690 non-null   object
#  6   IMDB_Score   1690 non-null   float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 92.6+ KB

# %%
df.describe()
# Out:
#                 ID   IMDB_Score
# count  1690.000000  1690.000000
# mean    844.500000     6.877337
# std     488.005294     2.690564
# min       0.000000     0.000000
# 25%     422.250000     6.900000
# 50%     844.500000     7.800000
# 75%    1266.750000     8.400000
# max    1689.000000     9.600000

# %%
df.shape
# Out:
# (1690, 7)

# %%
df.columns
# Out:
# Index(['ID', 'Movie', 'Year', 'Genre', 'RunTime', 'Description', 'IMDB_Score'], dtype='object')

# %%
df.dtypes
# Out:
# ID               int64
# Movie           object
# Year            object
# Genre           object
# RunTime         object
# Description     object
# IMDB_Score     float64
# dtype: object

# %%
df.memory_usage()
# Out:
# Index            132
# ID             13520
# Movie          13520
# Year           13520
# Genre          13520
# RunTime        13520
# Description    13520
# IMDB_Score     13520
# dtype: int64

# %%
df.nunique()
# Out:
# ID             1690
# Movie           314
# Year            147
# Genre            90
# RunTime         126
# Description    1571
# IMDB_Score       56
# dtype: int64

# %%
df['Movie']
# Out:
# 0                                Eternals
# 1                                    Loki
# 2       The Falcon and the Winter Soldier
# 3                             WandaVision
# 4                 Spider-Man: No Way Home
#                       ...
# 1685             DC's Legends of Tomorrow
# 1686                            Supergirl
# 1687                            Supergirl
# 1688                            Supergirl
# 1689                            Supergirl
# Name: Movie, Length: 1690, dtype: object

# %%
df[['Movie', 'Year']]
# Out:
#                                   Movie         Year
# 0                              Eternals        -2021
# 1                                  Loki     (2021– )
# 2     The Falcon and the Winter Soldier        -2021
# 3                           WandaVision        -2021
# 4               Spider-Man: No Way Home        -2021
# ...                                 ...          ...
# 1685           DC's Legends of Tomorrow     (2016– )
# 1686                          Supergirl  (2015–2021)
# 1687                          Supergirl  (2015–2021)
# 1688                          Supergirl  (2015–2021)
# 1689                          Supergirl  (2015–2021)
#
# [1690 rows x 2 columns]

# %%
df.loc[0]
# Out:
# ID                                                             0
# Movie                                                   Eternals
# Year                                                       -2021
# Genre                                     Action,Adventure,Drama
# RunTime                                                        0
# Description    The saga of the Eternals, a race of immortal b...
# IMDB_Score                                                   0.0
# Name: 0, dtype: object

# %%
df[df['IMDB_Score'] > 9.5]
# Out:
#         ID                   Movie         Year                       Genre  \
# 382    382  Agents of S.H.I.E.L.D.  (2013–2020)      Action,Adventure,Drama
# 1260  1260           Young Justice     (2010– )  Animation,Action,Adventure
# 1303  1303               The Flash     (2014– )      Action,Adventure,Drama
#
#      RunTime                                        Description  IMDB_Score
# 382   43 min  A time storm ravages the Zephyr, propelling it...         9.6
# 1260  22 min  The Light calls a summit to decide the final f...         9.6
# 1303  44 min  With the Particle Accelerator back online, Bar...         9.6

# %%
df.query('ID > 100 and IMDB_Score > 9')
# Out:
#         ID                   Movie         Year                    Genre  \
# 180    180             WandaVision        -2021      Action,Comedy,Drama
# 278    278  Agents of S.H.I.E.L.D.  (2013–2020)   Action,Adventure,Drama
# 283    283  Agents of S.H.I.E.L.D.  (2013–2020)   Action,Adventure,Drama
# 295    295  Agents of S.H.I.E.L.D.  (2013–2020)   Action,Adventure,Drama
# 308    308            The Punisher  (2017–2019)       Action,Crime,Drama
# ...    ...                     ...          ...                      ...
# 1576  1576               The Flash     (2014– )   Action,Adventure,Drama
# 1614  1614             Doom Patrol     (2019– )  Action,Adventure,Comedy
# 1625  1625                 Lucifer     (2016– )      Crime,Drama,Fantasy
# 1636  1636                Watchmen        -2019     Action,Drama,Mystery
# 1651  1651                Watchmen        -2019     Action,Drama,Mystery
#
#      RunTime                                        Description  IMDB_Score
# ...

# %%
df.isnull()
# Out:
#          ID  Movie   Year  Genre  RunTime  Description  IMDB_Score
# 0     False  False  False  False    False        False       False
# 1     False  False  False  False    False        False       False
# 2     False  False  False  False    False        False       False
# 3     False  False  False  False    False        False       False
# 4     False  False  False  False    False        False       False
# ...     ...    ...    ...    ...      ...          ...         ...
# 1685  False  False  False  False    False        False       False
# 1686  False  False  False  False    False        False       False
# 1687  False  False  False  False    False        False       False
# 1688  False  False  False  False    False        False       False
# 1689  False  False  False  False    False        False       False
#
# [1690 rows x 7 columns]

# %%
df.notnull()
# Out:
#         ID  Movie  Year  Genre  RunTime  Description  IMDB_Score
# 0     True   True  True   True     True         True        True
# 1     True   True  True   True     True         True        True
# 2     True   True  True   True     True         True        True
# 3     True   True  True   True     True         True        True
# 4     True   True  True   True     True         True        True
# ...    ...    ...   ...    ...      ...          ...         ...
# 1685  True   True  True   True     True         True        True
# 1686  True   True  True   True     True         True        True
# 1687  True   True  True   True     True         True        True
# 1688  True   True  True   True     True         True        True
# 1689  True   True  True   True     True         True        True
#
# [1690 rows x 7 columns]

# %%
 df.isnull().sum()
# Out:
# ID              0
# Movie           0
# Year           33
# Genre           7
# RunTime         0
# Description     0
# IMDB_Score      0
# dtype: int64

# %%
df.isnull()
# Out:
#          ID  Movie   Year  Genre  RunTime  Description  IMDB_Score
# 0     False  False  False  False    False        False       False
# 1     False  False  False  False    False        False       False
# 2     False  False  False  False    False        False       False
# 3     False  False  False  False    False        False       False
# 4     False  False  False  False    False        False       False
# ...     ...    ...    ...    ...      ...          ...         ...
# 1685  False  False  False  False    False        False       False
# 1686  False  False  False  False    False        False       False
# 1687  False  False  False  False    False        False       False
# 1688  False  False  False  False    False        False       False
# 1689  False  False  False  False    False        False       False
#
# [1690 rows x 7 columns]

# %%
df.notnull()
# Out:
#         ID  Movie  Year  Genre  RunTime  Description  IMDB_Score
# 0     True   True  True   True     True         True        True
# 1     True   True  True   True     True         True        True
# 2     True   True  True   True     True         True        True
# 3     True   True  True   True     True         True        True
# 4     True   True  True   True     True         True        True
# ...    ...    ...   ...    ...      ...          ...         ...
# 1685  True   True  True   True     True         True        True
# 1686  True   True  True   True     True         True        True
# 1687  True   True  True   True     True         True        True
# 1688  True   True  True   True     True         True        True
# 1689  True   True  True   True     True         True        True
#
# [1690 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# ID              0
# Movie           0
# Year           33
# Genre           7
# RunTime         0
# Description     0
# IMDB_Score      0
# dtype: int64

# %%
df=df[df['Year'].notnull()]
# games=games[games['PTS_home'].notnull()]

# %%
df.isnull().sum()
# Out:
# ID             0
# Movie          0
# Year           0
# Genre          7
# RunTime        0
# Description    0
# IMDB_Score     0
# dtype: int64

# %%
df=df[df['Genre'].notnull()]

# %%
df.isnull().sum()
# Out:
# ID             0
# Movie          0
# Year           0
# Genre          0
# RunTime        0
# Description    0
# IMDB_Score     0
# dtype: int64

# %%
dd=pd.read_csv('superhero.csv')

# %%
dd
# Out:
#                    Name Universe  Alignment  Strength  Speed  Intelligence  \
# 0           Iron Man #1   Marvel  Anti-Hero       1.0    1.0           2.0
# 1             Batman #1       DC  Anti-Hero       5.0    4.0           6.0
# 2              Joker #1   Marvel       Hero       3.0    9.0           2.0
# 3               Thor #1   Marvel       Hero       1.0    6.0           2.0
# 4             Thanos #1   Marvel    Villain       4.0    3.0           2.0
# ..                  ...      ...        ...       ...    ...           ...
# 195  Doctor Strange #10       DC    Villain       7.0    5.0           8.0
# 196            Hulk #10       DC  Anti-Hero       9.0    2.0           6.0
# 197         Aquaman #10       DC       Hero       3.0    3.0           7.0
# 198        Catwoman #10   Marvel       Hero       9.0    NaN           3.0
# 199       Wolverine #10   Marvel       Hero       1.0    6.0           NaN
#
#      Combat Skill  Weapon  Power Score  Popularity Score
# ...

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              200 non-null    object
#  1   Universe          200 non-null    object
#  2   Alignment         200 non-null    object
#  3   Strength          190 non-null    float64
#  4   Speed             190 non-null    float64
#  5   Intelligence      190 non-null    float64
#  6   Combat Skill      200 non-null    int64
#  7   Weapon            171 non-null    object
#  8   Power Score       200 non-null    int64
#  9   Popularity Score  200 non-null    int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 15.8+ KB

# %%
dd.isnull().sum()
# Out:
# Name                 0
# Universe             0
# Alignment            0
# Strength            10
# Speed               10
# Intelligence        10
# Combat Skill         0
# Weapon              29
# Power Score          0
# Popularity Score     0
# dtype: int64

# %%
dd=dd[dd['Strength'].notnull()]

# %%
dd.isnull().sum()
# Out:
# Name                 0
# Universe             0
# Alignment            0
# Strength             0
# Speed               10
# Intelligence        10
# Combat Skill         0
# Weapon              25
# Power Score          0
# Popularity Score     0
# dtype: int64

# %%
dd=dd[dd['Speed'].notnull()]

# %%
dd.isnull().sum()
# Out:
# Name                 0
# Universe             0
# Alignment            0
# Strength             0
# Speed                0
# Intelligence         9
# Combat Skill         0
# Weapon              24
# Power Score          0
# Popularity Score     0
# dtype: int64

# %%
dd=dd[dd['Weapon'].notnull()]

# %%
dd.isnull().sum()
# Out:
# Name                0
# Universe            0
# Alignment           0
# Strength            0
# Speed               0
# Intelligence        8
# Combat Skill        0
# Weapon              0
# Power Score         0
# Popularity Score    0
# dtype: int64

# %%
dd=dd[dd['Intelligence'].notnull()]

# %%
dd.isnull().sum()
# Out:
# Name                0
# Universe            0
# Alignment           0
# Strength            0
# Speed               0
# Intelligence        0
# Combat Skill        0
# Weapon              0
# Power Score         0
# Popularity Score    0
# dtype: int64

# %%
dd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 0 to 197
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              148 non-null    object
#  1   Universe          148 non-null    object
#  2   Alignment         148 non-null    object
#  3   Strength          148 non-null    float64
#  4   Speed             148 non-null    float64
#  5   Intelligence      148 non-null    float64
#  6   Combat Skill      148 non-null    int64
#  7   Weapon            148 non-null    object
#  8   Power Score       148 non-null    int64
#  9   Popularity Score  148 non-null    int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 12.7+ KB

# %%
dd.head()
# Out:
#           Name Universe  Alignment  Strength  Speed  Intelligence  \
# 0  Iron Man #1   Marvel  Anti-Hero       1.0    1.0           2.0
# 1    Batman #1       DC  Anti-Hero       5.0    4.0           6.0
# 2     Joker #1   Marvel       Hero       3.0    9.0           2.0
# 3      Thor #1   Marvel       Hero       1.0    6.0           2.0
# 4    Thanos #1   Marvel    Villain       4.0    3.0           2.0
#
#    Combat Skill  Weapon  Power Score  Popularity Score
# 0             5   Sword           65                40
# 1             2  Shield           94                98
# 2             5  Hammer           62                40
# 3             8   Claws           83                91
# 4             9   Claws           78                77

# %%
dd.describe()
# Out:
#          Strength       Speed  Intelligence  Combat Skill  Power Score  \
# count  148.000000  148.000000    148.000000    148.000000   148.000000
# mean     5.466216    5.493243      5.621622      5.290541    71.270270
# std      2.937942    2.844009      2.933284      2.914317    18.206523
# min      1.000000    1.000000      1.000000      1.000000    40.000000
# 25%      3.000000    3.000000      3.000000      3.000000    54.000000
# 50%      5.000000    5.000000      6.000000      5.000000    73.000000
# 75%      8.000000    8.000000      8.000000      8.000000    87.250000
# max     10.000000   10.000000     10.000000     10.000000   100.000000
#
#        Popularity Score
# count        148.000000
# mean          52.229730
# std           29.221671
# min            1.000000
# 25%           27.000000
# 50%           51.000000
# 75%           78.000000
# max          100.000000

# %%
dd['Strength']
# Out:
# 0      1.0
# 1      5.0
# 2      3.0
# 3      1.0
# 4      4.0
#       ...
# 193    1.0
# 194    7.0
# 195    7.0
# 196    9.0
# 197    3.0
# Name: Strength, Length: 148, dtype: float64

# %%
dd.query('Strength>4.0 and Speed>4.0')
# Out:
#                     Name Universe  Alignment  Strength  Speed  Intelligence  \
# 10               Loki #1   Marvel  Anti-Hero       9.0    7.0           1.0
# 13       Harley Quinn #1   Marvel  Anti-Hero      10.0   10.0          10.0
# 19          Wolverine #1   Marvel       Hero       7.0    5.0           8.0
# 21             Batman #2   Marvel       Hero      10.0    5.0          10.0
# 25       Wonder Woman #2       DC    Villain       8.0    5.0           5.0
# 30               Loki #2   Marvel  Anti-Hero      10.0    5.0           3.0
# 32           Superman #2       DC       Hero      10.0    7.0           7.0
# 35     Doctor Strange #2   Marvel  Anti-Hero       9.0   10.0           8.0
# 36               Hulk #2       DC    Villain       8.0   10.0           4.0
# 38           Catwoman #2   Marvel       Hero       7.0    6.0           4.0
# 39          Wolverine #2   Marvel       Hero       9.0    7.0           8.0
# ...

# %%
dd.head()
# Out:
#           Name Universe  Alignment  Strength  Speed  Intelligence  \
# 0  Iron Man #1   Marvel  Anti-Hero       1.0    1.0           2.0
# 1    Batman #1       DC  Anti-Hero       5.0    4.0           6.0
# 2     Joker #1   Marvel       Hero       3.0    9.0           2.0
# 3      Thor #1   Marvel       Hero       1.0    6.0           2.0
# 4    Thanos #1   Marvel    Villain       4.0    3.0           2.0
#
#    Combat Skill  Weapon  Power Score  Popularity Score
# 0             5   Sword           65                40
# 1             2  Shield           94                98
# 2             5  Hammer           62                40
# 3             8   Claws           83                91
# 4             9   Claws           78                77

# %%
dd.shape
# Out:
# (148, 10)

# %%
dd['Weapon']
# Out:
# 0       Sword
# 1      Shield
# 2      Hammer
# 3       Claws
# 4       Claws
#         ...
# 193    Hammer
# 194       Bow
# 195     Sword
# 196    Shield
# 197     Sword
# Name: Weapon, Length: 148, dtype: object

# %%
dd['Weapon'].unique()
# Out:
# array(['Sword', 'Shield', 'Hammer', 'Claws', 'Bow', 'Psychic', 'Magic',
#        'Tech'], dtype=object)

# %%
dd.at[1,'Weapon']='Tech'

# %%
dd['Weapon']
# Out:
# 0       Sword
# 1        Tech
# 2      Hammer
# 3       Claws
# 4       Claws
#         ...
# 193    Hammer
# 194       Bow
# 195     Sword
# 196    Shield
# 197     Sword
# Name: Weapon, Length: 148, dtype: object

# %%
dd.at[1,'Weapon']='Rich'

# %%
dd['Weapon']
# Out:
# 0       Sword
# 1        Rich
# 2      Hammer
# 3       Claws
# 4       Claws
#         ...
# 193    Hammer
# 194       Bow
# 195     Sword
# 196    Shield
# 197     Sword
# Name: Weapon, Length: 148, dtype: object

# %%
dd.at[0,'Weapon']='Tech'

# %%
dd['Weapon']
# Out:
# 0        Tech
# 1        Rich
# 2      Hammer
# 3       Claws
# 4       Claws
#         ...
# 193    Hammer
# 194       Bow
# 195     Sword
# 196    Shield
# 197     Sword
# Name: Weapon, Length: 148, dtype: object

# %%
dd
# Out:
#                    Name Universe  Alignment  Strength  Speed  Intelligence  \
# 0           Iron Man #1   Marvel  Anti-Hero       1.0    1.0           2.0
# 1             Batman #1       DC  Anti-Hero       5.0    4.0           6.0
# 2              Joker #1   Marvel       Hero       3.0    9.0           2.0
# 3               Thor #1   Marvel       Hero       1.0    6.0           2.0
# 4             Thanos #1   Marvel    Villain       4.0    3.0           2.0
# ..                  ...      ...        ...       ...    ...           ...
# 193    Harley Quinn #10   Marvel    Villain       1.0    7.0           1.0
# 194           Flash #10   Marvel       Hero       7.0    5.0           9.0
# 195  Doctor Strange #10       DC    Villain       7.0    5.0           8.0
# 196            Hulk #10       DC  Anti-Hero       9.0    2.0           6.0
# 197         Aquaman #10       DC       Hero       3.0    3.0           7.0
#
#      Combat Skill  Weapon  Power Score  Popularity Score
# ...

# %%
dd.at[2,'Weapon']='venom'

# %%
dd.head()
# Out:
#           Name Universe  Alignment  Strength  Speed  Intelligence  \
# 0  Iron Man #1   Marvel  Anti-Hero       1.0    1.0           2.0
# 1    Batman #1       DC  Anti-Hero       5.0    4.0           6.0
# 2     Joker #1   Marvel       Hero       3.0    9.0           2.0
# 3      Thor #1   Marvel       Hero       1.0    6.0           2.0
# 4    Thanos #1   Marvel    Villain       4.0    3.0           2.0
#
#    Combat Skill Weapon  Power Score  Popularity Score
# 0             5   Tech           65                40
# 1             2   Rich           94                98
# 2             5  venom           62                40
# 3             8  Claws           83                91
# 4             9  Claws           78                77

# %%
dd.at[3,'Weapon']='Hammer'

# %%
dd.head()
# Out:
#           Name Universe  Alignment  Strength  Speed  Intelligence  \
# 0  Iron Man #1   Marvel  Anti-Hero       1.0    1.0           2.0
# 1    Batman #1       DC  Anti-Hero       5.0    4.0           6.0
# 2     Joker #1   Marvel       Hero       3.0    9.0           2.0
# 3      Thor #1   Marvel       Hero       1.0    6.0           2.0
# 4    Thanos #1   Marvel    Villain       4.0    3.0           2.0
#
#    Combat Skill  Weapon  Power Score  Popularity Score
# 0             5    Tech           65                40
# 1             2    Rich           94                98
# 2             5   venom           62                40
# 3             8  Hammer           83                91
# 4             9   Claws           78                77
